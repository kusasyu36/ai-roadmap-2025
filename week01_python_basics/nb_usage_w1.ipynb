# %% [markdown]
# <a href="https://colab.research.google.com/github/kusasyu36/ai-roadmap-2025/blob/main/week01_python_basics/nb_usage_w1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# --- ここだけ自分のユーザー名に変えてください ---
GITHUB_USER = "kusasyu36"
# -----------------------------------------------------

# GitHub raw URL から utils_day5.py をダウンロードして、カレントに保存
# !wget -q -O utils_day5.py https://raw.githubusercontent.com/{GITHUB_USER}/ai-roadmap-2025/main/week01_python_basics/utils_day5.py

# ちゃんと取れたか確認
# !ls -l utils_day5.py
# Out:
# -rw-r--r-- 1 root root 3196 Nov  4 08:25 utils_day5.py

# %%
import utils_day5 as U

# %%
print(U.is_palindrome("Never odd or even"))
# Out:
# True

# %%
print(U.ngram("pneumonoultramicroscopicsilicovolcanoconiosis", 5))
# Out:
# ['pneum', 'neumo', 'eumon', 'umono', 'monou', 'onoul', 'noult', 'oultr', 'ultra', 'ltram', 'trami', 'ramic', 'amicr', 'micro', 'icros', 'crosc', 'rosco', 'oscop', 'scopi', 'copic', 'opics', 'picsi', 'icsil', 'csili', 'silic', 'ilico', 'licov', 'icovo', 'covol', 'ovolc', 'volca', 'olcan', 'lcano', 'canoc', 'anoco', 'nocon', 'oconi', 'conio', 'onios', 'niosi', 'iosis']

# %%
print(U.ngram("dictionary", 5))
# Out:
# ['dicti', 'ictio', 'ction', 'tiona', 'ionar', 'onary']

# %%
print(U.grade(83))
# Out:
# B

# %%
print(U.bmi_class(1.70, 68))
# Out:
# 普通体重

# %% [markdown]
# 	4.	コードをGitHubで更新した場合は、Colab側で再ダウンロードすれば反映されます

# %%
# GitHubを更新したあとに再取得
# !wget -q -O utils_day5.py https://raw.githubusercontent.com/{GITHUB_USER}/ai-roadmap-2025/main/week01_python_basics/utils_day5.py

# すでにimport済みなら、再読み込み
import importlib, utils_day5
importlib.reload(utils_day5)
# Out:
# <module 'utils_day5' from '/content/utils_day5.py'>

# %%
# 1) ライブラリ読込
import textwrap, pandas as pd
import utils_day5 as U  # week01_python_basics配下の実装を使う

# %%
# 2) 関数の使用例（出力が“絵”になるよう、printで明示）
s = "Never odd or even"
print("is_palindrome:", U.is_palindrome(s))

print("ngram:", U.ngram("TOKYO", 2))

# txt = "Time flies like an arrow. Time and tide wait for no man."
# print("word_count_en:", U.word_count_en(txt)[:10])

print("grade:", U.grade(83))
print("bmi_class (170cm/68kg):", U.bmi_class(1.70, 68))
# Out:
# is_palindrome: True
# ngram: ['TO', 'OK', 'KY', 'YO']
# grade: B
# bmi_class (170cm/68kg): 普通体重

# %%
md = f"""
## 実行例

```python
import utils_day5 as U

U.is_palindrome("Never odd or even")  # → {U.is_palindrome("Never odd or even")}
U.ngram("TOKYO", 2)                   # → {U.ngram("TOKYO", 2)}
U.word_count_en("Time flies like an arrow. Time and tide wait for no man.")[:5]
# → {U.word_count_en("Time flies like an arrow. Time and tide wait for no man.")[:5]}
U.grade(83)                           # → {U.grade(83)}
U.bmi_class(1.70, 68)                 # → {U.bmi_class(1.70, 68)}
“””
print(md)
# Out:
#   File "/tmp/ipython-input-3306351439.py", line 1
#     md = f"""
#          ^
# SyntaxError: incomplete input
